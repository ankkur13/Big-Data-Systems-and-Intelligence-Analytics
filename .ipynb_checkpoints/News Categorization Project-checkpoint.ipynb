# %%
#importing important libraries for the project
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import missingno as msno

# %%
df=pd.read_csv("Backup_scrap_big data.csv",encoding='ISO-8859-1',engine='python',error_bad_lines=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42637 entries, 0 to 42636
# Data columns (total 7 columns):
# ï»¿Title          42636 non-null object
# Authors           41665 non-null object
# Text              42563 non-null object
# Image             0 non-null float64
# Videos            0 non-null float64
# Link              42635 non-null object
# Published_Date    42622 non-null object
# dtypes: float64(2), object(5)
# memory usage: 2.3+ MB

# %%
df['Title']=df['ï»¿Title']

# %%
df.describe()
# Out:
#        Image  Videos
# count    0.0     0.0
# mean     NaN     NaN
# std      NaN     NaN
# min      NaN     NaN
# 25%      NaN     NaN
# 50%      NaN     NaN
# 75%      NaN     NaN
# max      NaN     NaN

# %% [markdown]
# Since the Images and Videos columns are having very less value, We can drop these and also they are not important for further analysis

# %%
df=df.drop(columns=['Image', 'Videos'],axis=1)

# %% [markdown]
# To check the missing value in the columns

# %%
# Checking Null Values
df.apply(lambda x: sum(x.isnull()), axis=0)
# Out:
# ï»¿Title            1
# Authors           972
# Text               74
# Link                2
# Published_Date     15
# Title               1
# dtype: int64

# %%
# Matrix of missingness of the data
msno.matrix(df.sample(500), figsize=(14, 5), width_ratios=(14, 1));

# %% [markdown]
# The above picture shows that the dataset contain some missing values. We need to drop them.

# %%
df=df.dropna(axis=0, how='any')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41591 entries, 0 to 42636
# Data columns (total 6 columns):
# ï»¿Title          41591 non-null object
# Authors           41591 non-null object
# Text              41591 non-null object
# Link              41591 non-null object
# Published_Date    41591 non-null object
# Title             41591 non-null object
# dtypes: object(6)
# memory usage: 2.2+ MB

# %% [markdown]
# No of Articles published by authors

# %%
z=df.groupby(by=['Authors'],as_index=False).count().sort_values(by='Link',ascending=False).head(10)

plt.figure(figsize=(15,15))
sns.set_style("whitegrid")
ax = sns.barplot(x=z['Authors'],y=z['Link'], data=z)
plt.xlabel("Author")
plt.ylabel("Count")
plt.title("Counts Vs Authors")
# Out:
# Text(0.5,1,'Counts Vs Authors')

# %% [markdown]
# Count the frequency of each word and display the words which are occuring most in Title column.

# %%
#!pip install stop_words
#!pip install wordcloud

from collections import Counter
from nltk.tokenize import RegexpTokenizer
from stop_words import get_stop_words
import nltk
from nltk.corpus import stopwords
from nltk import sent_tokenize, word_tokenize
from wordcloud import WordCloud, STOPWORDS
import re
#import nltk
#nltk.download('punkt')
#nltk.download('stopwords')

top_N = 100
#convert list of list into text
#a=''.join(str(r) for v in df_usa['title'] for r in v)

a = df['Title'].str.lower().str.cat(sep=' ')

# removes punctuation,numbers and returns list of words
b = re.sub('[^A-Za-z]+', ' ', a)

#remove all the stopwords from the text
stop_words = list(get_stop_words('en'))         
nltk_words = list(stopwords.words('english'))   
stop_words.extend(nltk_words)

word_tokens = word_tokenize(b)
filtered_sentence = [w for w in word_tokens if not w in stop_words]
filtered_sentence = []
for w in word_tokens:
    if w not in stop_words:
        filtered_sentence.append(w)

# Remove characters which have length less than 2  
without_single_chr = [word for word in filtered_sentence if len(word) > 2]

# Remove numbers
cleaned_data_title = [word for word in without_single_chr if not word.isnumeric()]        

# Calculate frequency distribution
word_dist = nltk.FreqDist(cleaned_data_title)
rslt = pd.DataFrame(word_dist.most_common(top_N),
                    columns=['Word', 'Frequency'])

plt.figure(figsize=(15,15))
sns.set_style("whitegrid")
ax = sns.barplot(x="Word",y="Frequency", data=rslt.head(7))

# %%
#Function to show the wordcloud for the Title column
def wc(data,bgcolor,title):
    plt.figure(figsize = (100,100))
    wc = WordCloud(background_color = bgcolor, max_words = 1000,  max_font_size = 50)
    wc.generate(' '.join(data))
    plt.imshow(wc)
    plt.axis('off')

# %%
wc(cleaned_data_title,'black','Most Used Words')

# %%
#!pip install textblob
from textblob import TextBlob

bloblist_desc = list()

df_review_str=df['Title'].astype(str)
for row in df_review_str:
    blob = TextBlob(row)
    bloblist_desc.append((row,blob.sentiment.polarity, blob.sentiment.subjectivity))
    df_polarity_desc = pd.DataFrame(bloblist_desc, columns = ['title','sentiment','polarity'])

def f(df_polarity_desc):
    if df_polarity_desc['sentiment'] > 0:
        val = "Positive Title"
    elif df_polarity_desc['sentiment'] == 0:
        val = "Neutral Title"
    else:
        val = "Negative Title"
    return val

df_polarity_desc['Sentiment_Type'] = df_polarity_desc.apply(f, axis=1)

plt.figure(figsize=(10,10))
sns.set_style("whitegrid")
ax = sns.countplot(x="Sentiment_Type", data=df_polarity_desc)

# %% [markdown]
# Count the frequency of each word and display the words which are occuring most in Text column.

# %%
#!pip install stop_words
#!pip install wordcloud

from collections import Counter
from nltk.tokenize import RegexpTokenizer
from stop_words import get_stop_words
import nltk
from nltk.corpus import stopwords
from nltk import sent_tokenize, word_tokenize
from wordcloud import WordCloud, STOPWORDS
import re
#import nltk
#nltk.download('punkt')
#nltk.download('stopwords')

top_N = 100
#convert list of list into text
#a=''.join(str(r) for v in df_usa['title'] for r in v)

a = df['Text'].str.lower().str.cat(sep=' ')

# removes punctuation,numbers and returns list of words
b = re.sub('[^A-Za-z]+', ' ', a)

#remove all the stopwords from the text
stop_words = list(get_stop_words('en'))         
nltk_words = list(stopwords.words('english'))   
stop_words.extend(nltk_words)

word_tokens = word_tokenize(b)
filtered_sentence = [w for w in word_tokens if not w in stop_words]
filtered_sentence = []
for w in word_tokens:
    if w not in stop_words:
        filtered_sentence.append(w)

# Remove characters which have length less than 2  
without_single_chr = [word for word in filtered_sentence if len(word) > 2]

# Remove numbers
cleaned_data_title = [word for word in without_single_chr if not word.isnumeric()]        

# Calculate frequency distribution
word_dist = nltk.FreqDist(cleaned_data_title)
rslt = pd.DataFrame(word_dist.most_common(top_N),
                    columns=['Word', 'Frequency'])

plt.figure(figsize=(15,15))
sns.set_style("whitegrid")
ax = sns.barplot(x="Word",y="Frequency", data=rslt.head(7))

# %%
wc(cleaned_data_title,'black','Most Used Words')

# %%
#!pip install textblob
from textblob import TextBlob

bloblist_desc = list()

df_review_str=df['Text'].astype(str)
for row in df_review_str:
    blob = TextBlob(row)
    bloblist_desc.append((row,blob.sentiment.polarity, blob.sentiment.subjectivity))
    df_polarity_desc = pd.DataFrame(bloblist_desc, columns = ['title','sentiment','polarity'])

def f(df_polarity_desc):
    if df_polarity_desc['sentiment'] > 0:
        val = "Positive Title"
    elif df_polarity_desc['sentiment'] == 0:
        val = "Neutral Title"
    else:
        val = "Negative Title"
    return val

df_polarity_desc['Sentiment_Type'] = df_polarity_desc.apply(f, axis=1)

plt.figure(figsize=(10,10))
sns.set_style("whitegrid")
ax = sns.countplot(x="Sentiment_Type", data=df_polarity_desc)

# %%
df['Published_Date'] = pd.to_datetime(df['Published_Date'],utc=True, format= "%m/%d/%Y")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     302             try:
# --> 303                 values, tz = tslib.datetime_to_datetime64(arg)
#     304                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-142-acdb2bc84dbb> in <module>()
# ----> 1 df['Published_Date'] = pd.to_datetime(df['Published_Date'],utc=True, format= "%m/%d/%Y")
#
# ...
